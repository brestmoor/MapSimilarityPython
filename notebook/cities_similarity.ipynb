# %% [markdown]
# ## Eksperymenty:
#
# Kursywą zostały wyróżnione zapytania grafowe.
#
# roads:
# - average_street_length
# - intersection_density_km
# - street_density_km
# - *circuity_avg (stosunek odległości poruszając się po sieci dróg, do odległości w linii prostej)*
# - one_way_percentage (udział ulic jednokierunkowych)
# - primary_percentage (udział ulic pierwszorzędnych)
# - share_of_separated_streets (udział ulic w sąsiedztwie których (50m) jest mniej niż 3 ulice)
# - streets_in_radius_of_100_m (ile średnio jest ulic w odległości 100m od każdej ulicy)
# - avg_dist_between_crossroads
#
# buildings_and_terrain:
# - average_dist_to_park (średnia odległość z miejsca zamieszkania do najbliższego parku)
# - average_dist_to_bus_stop (średnia odległość z miejsca zamieszkania do najbliższego przystanku autobusowego)
# - buildings_coverage
# - natural_terrain_coverage
#
# buses_and_cycleways:
# - average_dist_to_bus_stop (średnia odległość z miejsca zamieszkania do najbliższego przystanku autobusowego)
# - bus_routes_to_highways (stosunek długości linii autobusowych do długości ulic)
# - cycleways_to_highways (stosunek długości alejek rowerowych do długości ulic)
# - tram_routes_to_highways (stosunek długości linii tramwajowych do długości ulic)
#
# subway:
# - *average_how_many_subway_routes_are_there_from_one_stop_to_another*
# - *how_many_failures_can_network_handle* (na ilu odcinach metra może nastąpić awaria, a mimo to wszystkie połączenia zostaną zachowane)
#
# facilities:
# - *avg_short_distances_between_hospitals*
# - *avg_short_distances_between_train_stations_and_city_center* (średnia z najkrotszych odleglosci miedzy stacja kolejowa a centrum miasta)
# - *longest_cycleway_network* (jaką długość ma najwiekszy podgraf w sieci alejek rowerowych)
#
#
# all_functions (wszystkie kryteria)

# %%
import sys
sys.path.append('../')
from run import run
from IPython.display import display

#zwracane są 2 macierze. Macierz z wynikami zapytań dla danego miasta oraz Macierz podobieństw między miastami (od 0 do 1)
scores_df, similarity_df = run('compare_buses.json') 
display(scores_df)
display(similarity_df)
# Out:
# run for compare_buses.json took: 319.3104556999999
#                              Krakow, Poland  Katowice, Poland  \
# average_street_length            163.523611        124.664876
# intersection_density_km           14.767924         24.680522
# street_density_km               4158.116305       5108.507715
# circuity_avg                       1.068498          1.058082
# one_way_percentage                 0.383859          0.402025
# primary_percentage                 0.121614          0.075243
# share_of_separated_streets         0.129685          0.124082
# streets_in_radius_of_100_m        12.281076         12.594997
# avg_dist_between_crossroads      100.000292        106.629942
#
#                              Wroclaw, Poland  Kielce, Poland  Poznan, Poland  \
# average_street_length             151.921058      149.141872      136.803593
# intersection_density_km            14.049081       16.723358       17.968485
# ...
